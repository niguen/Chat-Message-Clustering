# %%
import pandas as pd
import os
os.chdir("..")

chatbot = 'roberta'
model = 'LDA'
run = 'LDA_32_roberta'


path = os.path.join('output', chatbot, model, run, 'topics.xlsx')

# %%
df = pd.read_excel(path)
df
# Out:
#     Unnamed: 0                                        Topic words  \
# 0            0       grüsse, Adresse, Offerte, Aufnahme, erhalten
# 1            1              neu, x, eigenstrom, anderer, variante
# 2            2  ekz, Strassenlaterne, Überbauung, Wackelkontak...
# 3            3          alt, ändern, melden, Streichung, Passwort
# 4            4                       kw, ändern, Vorperiode, i, h
# 5            5               ekz, elektriker, matti, fritschi, ch
# 6            6          kw, Kontrolle, Stromnetz, intern, Vertrag
# 7            7                            per, d, Blum, ch, danke
# 8            8            Jahr, finden, pro, Verbräuche, erhalten
# 9            9  eingeben, Leistung, stimmen, verbrauchsstell, ...
# 10          10              finden, Land, hab, inklusive, webseit
# 11          11  Frage, Resp, betreffend, Kundenservice, Strome...
# 12          12  Stromverbrauch, Kundennummer, april, Jahr, Rüe...
# 13          13        pv, eigenstom, Niutzung, unternehmen, strom
# 14          14   ekz, Anmeldung, mixstrom, solaranliegen, Magazin
# 15          15                      möchten, e, ekz, Angebot, Tag
# 16          16  kraftwer, Unternehmen, tarif, Balkon, schweize...
# 17          17          Benutzernahme, Auge, lesen, gmx, Internet
# 18          18             Ckw, basis, verkaufen, bekommen, April
# 19          19  chf, app, Elektrizitätstarif, monat, Tarifände...
# 20          20  Tarif, unbekannt, Feiertage, Wechsel, schweize...
# 21          21                               kw, min, auto, km, e
# 22          22          verschieden, bitte, Jahr, kunummer, login
# 23          23  Verbrauch, Mann, jahresgesamt, stromlieferant,...
# 24          24     einspeisung, wohnen, melden, Embrach, vergesen
# 25          25    melden, Anmeldung, abschließen, evu, erscheinen
# 26          26       finden, Bonus, updates, Energietarife, Sorry
# 27          27  Frage, Wechselrichter, Solaranlage, ekz, Netza...
# 28          28         wieso, übersichen, verbrauchstell, FR, Kwh
# 29          29           Schweizer, ändern, schließen, einfach, e
# 30          30   bauprojekt, schweizerisch, Gartenweg, folgend, d
# 31          31  Tarif, aufladen, Tagseit, Parkplatz, installierte
#
#     Message count
# 0              71
# 1               8
# 2               8
# 3               8
# 4              12
# 5               6
# 6               6
# 7               8
# 8               5
# 9               4
# 10              7
# 11              5
# 12              8
# 13              6
# 14              4
# 15              7
# 16              5
# 17              3
# 18              6
# 19              5
# 20              5
# 21              5
# 22             12
# 23              4
# 24              2
# 25              8
# 26              9
# 27              7
# 28              6
# 29              8
# 30              1
# 31              6

# %%
table_str = df.to_latex(index=False, float_format="{:.3f}".format)

with open("table_topic_words.txt", "w") as text_file:
    text_file.write(table_str)
