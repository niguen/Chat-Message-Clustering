# %%
import pandas as pd
import os

input_file = os.path.join('roberta_fallback_labeled.xlsx')

# %%
df = pd.read_excel(input_file)
df
# Out:
#      Unnamed: 0.1  Unnamed: 0                  Received At  \
# 0               0           0   2023-01-23 09:14:29.825000
# 1               1          56   2023-02-13 15:13:38.980000
# 2               2          75   2023-02-20 09:21:09.348000
# 3               3          79   2023-02-20 14:06:35.434000
# 4               4          68   2023-03-24 07:36:20.763000
# ..            ...         ...                          ...
# 601           601          29  2023-06-15T09:05:30.295241Z
# 602           602          32  2023-06-14T07:43:13.893192Z
# 603           603          75  2023-06-06T15:24:57.592433Z
# 604           604          46  2023-06-12T14:38:30.248852Z
# 605           605          68  2023-06-09T05:26:09.839736Z
#
#                                                Message        Topic  \
# 0                                    Sehr geehrte Dame    begrüßung
# 1                                              hallo !    begrüßung
# 2                                                hallo    begrüßung
# 3                                              Bonjour    begrüßung
# 4                                           Jemand da?    begrüßung
# ..                                                 ...          ...
# 601                                 Fragen zur Mahnung      mahnung
# 602  Kann ich das EKZ-Magazin auch im Internet lese...      magazin
# 603  Können sie bitte folgende Adresse aus ihrem bl...      magazin
# 604                                         Bauprojekt       neubau
# 605                                         datenschtz  datenschutz
#
#      existing Topic
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ..              ...
# 601           False
# 602           False
# 603           False
# 604           False
# 605           False
#
# [606 rows x 6 columns]

# %%
df_irrelevant = df.loc[df['Topic'] == 'x']
df_irrelevant
# Out:
#      Unnamed: 0.1  Unnamed: 0                  Received At       Message  \
# 302           302         108   2023-01-02 12:07:29.512000             l
# 303           303         109   2023-01-03 20:55:53.231000  Meine Wie gr
# 304           304         110   2023-01-05 11:41:03.075000          test
# 305           305         111   2023-01-06 08:56:58.488000        stelle
# 306           306         112   2023-01-06 09:26:23.533000     formulare
# ..            ...         ...                          ...           ...
# 477           477          79  2023-06-05T21:09:51.848964Z             F
# 478           478          83  2023-06-05T12:25:38.570713Z  Druckfehler?
# 479           479          84  2023-06-05T09:31:51.312891Z             ?
# 480           480          87  2023-06-03T17:40:13.842434Z   Juchstrasse
# 481           481          90  2023-06-02T17:10:11.898940Z             ?
#
#     Topic  existing Topic
# 302     x            True
# 303     x            True
# 304     x            True
# 305     x            True
# 306     x            True
# ..    ...             ...
# 477     x            True
# 478     x            True
# 479     x            True
# 480     x            True
# 481     x            True
#
# [180 rows x 6 columns]

# %%
def is_irrelavent(message: str) -> bool:
    
    # message contains space
    if  ' ' not in message:
        return False

    # message contains no character
    # if 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ' not in message:
    #     return False

    return True

# %%
df_irrelevant['is irrelevant'] = df_irrelevant['Message'].apply(is_irrelavent)
# Out:
# C:\Users\NGuenther\AppData\Local\Temp\ipykernel_3248\3853297633.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_irrelevant['is irrelevant'] = df_irrelevant['Message'].apply(is_irrelavent)

# %%
df_irrelevant.loc[df_irrelevant['is irrelevant'] == True]
# Out:
#      Unnamed: 0.1  Unnamed: 0                  Received At  \
# 303           303         109   2023-01-03 20:55:53.231000
# 308           308         114   2023-01-09 07:58:26.594000
# 311           311         117   2023-01-11 12:03:26.135000
# 312           312         118   2023-01-11 12:03:41.961000
# 313           313         119   2023-01-11 14:34:14.641000
# ..            ...         ...                          ...
# 468           468          54  2023-06-09T14:15:43.718882Z
# 469           469          55  2023-06-09T14:15:09.563715Z
# 470           470          57  2023-06-09T13:25:20.727323Z
# 471           471          60  2023-06-09T13:20:39.718517Z
# 476           476          76  2023-06-06T12:04:03.201527Z
#
#                  Message Topic  existing Topic  is irrelevant
# 303         Meine Wie gr     x            True           True
# 308         IST GESPERRT     x            True           True
# 311          Wo ist Alex     x            True           True
# 312       Herr Schreiner     x            True           True
# 313         Paul Forster     x            True           True
# ..                   ...   ...             ...            ...
# 468  2. Stromnetz-Anlage     x            True           True
# 469  1. Stromnetz-Region     x            True           True
# 470    Habe ja angegeben     x            True           True
# 471          8180 Bülach     x            True           True
# 476             test bpc     x            True           True
#
# [81 rows x 7 columns]
